# %%
import requests
import os
import time
import sys
import json
import math
from collections import defaultdict

# --- 1. CONFIGURACIÓN DEL SCRIPT ---
# ==========================================================
# ¡¡DEFINE EL TIEMPO TOTAL QUE QUIERES QUE CORRA EL SCRIPT (en minutos)!!
#
DURACION_TOTAL_MINUTOS = 300# Por ejemplo, 120 minutos (2 horas)
#
# ==========================================================

# Convertir la duración a segundos para la lógica interna
DURACION_TOTAL_SEGUNDOS = DURACION_TOTAL_MINUTOS * 60

# --- Rutas de Archivos ---
INPUT_FILE_PATH = "/kaggle/input/mi-lista-de-descarga/descarga_lista.jsonl"
BASE_OUTPUT_FOLDER = "/kaggle/working/imagenes_muestreadas_por_tiempo"
METADATA_OUTPUT_FILE = "/kaggle/working/metadata_muestra_por_tiempo.json"

# --- 2. LEER Y PRE-PROCESAR EL ARCHIVO JSONL ---
print(f"Iniciando Muestreo: El script se ejecutará por {DURACION_TOTAL_MINUTOS} minutos.")
print(f"Leyendo archivo: {INPUT_FILE_PATH}")

try:
    with open(INPUT_FILE_PATH, 'r') as f:
        all_images_data = [json.loads(line) for line in f if line.strip()]
except FileNotFoundError:
    print(f"Error: No se encontró '{INPUT_FILE_PATH}'.")
    sys.exit()

total_disponible = len(all_images_data)
if not all_images_data:
    print("El archivo JSONL está vacío. Saliendo.")
    sys.exit()

print(f"Se leerán {total_disponible} imágenes candidatas.")

# --- Organizar todas las imágenes por BBOX ---
data_by_bbox = defaultdict(list)
for img_data in all_images_data:
    try:
        data_by_bbox[img_data['bbox_index']].append(img_data)
    except KeyError:
        pass # Ignorar líneas corruptas

total_bboxes_con_imagenes = len(data_by_bbox)
print(f"Imágenes organizadas en {total_bboxes_con_imagenes} BBOXes únicos.")


# --- 3. BUCLE COMBINADO DE SELECCIÓN Y DESCARGA POR TIEMPO ---
print(f"\nIniciando descarga. Tiempo límite: {DURACION_TOTAL_MINUTOS} minutos.")
os.makedirs(BASE_OUTPUT_FOLDER, exist_ok=True)

# Registrar el tiempo de inicio y calcular el tiempo de finalización
script_start_time = time.time()
script_end_time = script_start_time + DURACION_TOTAL_SEGUNDOS

metadata_procesada = [] # Aquí guardaremos la metadata de las imágenes que procesamos
current_depth = 0       # Profundidad/Ronda del "Round Robin"
processed_count = 0     # Contador de imágenes procesadas

try:
    # El bucle principal ahora se basa en el TIEMPO
    while time.time() < script_end_time:
        
        images_added_in_this_round = 0
        print(f"\nIniciando Ronda 'Round Robin' Nivel {current_depth}...")
        
        # Damos una vuelta por todos los BBOXes (ordenados del 1 al 120...)
        for bbox_index in sorted(data_by_bbox.keys()):
            
            # --- VERIFICACIÓN DE TIEMPO (INTERNA) ---
            # Verificamos el tiempo ANTES de procesar cada BBOX
            if time.time() >= script_end_time:
                print("\n¡Tiempo límite alcanzado! Deteniendo el bucle 'for' interno.")
                break # Romper el bucle 'for' interno
            
            # ¿Este BBOX todavía tiene una imagen en esta "ronda" (profundidad)?
            if current_depth < len(data_by_bbox[bbox_index]):
                
                # ¡Sí! La tomamos para procesar.
                img_data = data_by_bbox[bbox_index][current_depth]
                metadata_procesada.append(img_data) # La añadimos a la metadata
                images_added_in_this_round += 1
                processed_count += 1
                
                # Imprimir barra de progreso
                if processed_count % 5 == 0:
                    tiempo_restante = script_end_time - time.time()
                    print(f"Progreso: {processed_count} imágenes procesadas... Tiempo restante: {tiempo_restante:.0f}s   ", end="\r")
                
                # --- FASE DE DESCARGA INMEDIATA ---
                try:
                    download_url = img_data['download_url']
                    filename = img_data['filename']
                    file_path = os.path.join(BASE_OUTPUT_FOLDER, filename)
                    
                    if os.path.exists(file_path):
                        continue
                        
                    img_response = requests.get(download_url, timeout=10)
                    if img_response.status_code == 200:
                        with open(file_path, 'wb') as img_f:
                            img_f.write(img_response.content)
                            
                except Exception as e:
                    print(f"\nError al descargar ID {img_data.get('id', 'N/A')}. Omitiendo: {e}")
                    pass
                # --- Fin de la descarga ---

        # --- VERIFICACIÓN DE TIEMPO (EXTERNA) ---
        # Verificamos el tiempo después de completar una ronda entera
        if time.time() >= script_end_time:
            print("\n¡Tiempo límite alcanzado! Deteniendo el bucle 'while' externo.")
            break # Romper el bucle 'while' externo
        
        # ¿Nos quedamos sin imágenes antes de tiempo?
        if images_added_in_this_round == 0:
            print(f"\nSe agotaron todas las imágenes disponibles ({processed_count} procesadas) antes del límite de tiempo.")
            break # No hay más imágenes que añadir

        # Pasamos a la siguiente ronda (ej. buscar la 2da imagen de cada BBOX)
        current_depth += 1

except KeyboardInterrupt:
    print("\n¡Interrupción manual detectada! Pasando al reporte final.")
    pass # Permite al usuario detener con Ctrl+C y aun así guardar el reporte

# --- 4. REPORTE FINAL Y GUARDADO DE METADATA ---
script_end_runtime = time.time()
total_runtime_segundos = script_end_runtime - script_start_time
total_descargado = len(os.listdir(BASE_OUTPUT_FOLDER)) # Contar archivos reales

print(f"\nProceso detenido. Guardando metadata de {len(metadata_procesada)} imágenes procesadas...")

# Guardar el archivo de metadata en la carpeta de output
print(f"Guardando metadata en '{METADATA_OUTPUT_FILE}'...")
with open(METADATA_OUTPUT_FILE, 'w') as meta_f:
    json.dump(metadata_procesada, meta_f, indent=2)

print("\n" + "="*30)
print("--- MUESTREO POR TIEMPO COMPLETADO ---")
print(f"Tiempo Objetivo: {DURACION_TOTAL_MINUTOS:.2f} minutos.")
print(f"Tiempo Real de Ejecución: {total_runtime_segundos / 60:.2f} minutos ({total_runtime_segundos:.0f} segundos).")
print(f"Imágenes Únicas Descargadas: {total_descargado}")
print(f"Total Imágenes Procesadas (Metadata): {len(metadata_procesada)}")
print(f"Imágenes guardadas en: '{BASE_OUTPUT_FOLDER}'")
print(f"Metadata guardada en: '{METADATA_OUTPUT_FILE}'")
print("="*30)
# Out:
# Iniciando Muestreo: El script se ejecutará por 300 minutos.
# Leyendo archivo: /kaggle/input/mi-lista-de-descarga/descarga_lista.jsonl
# Se leerán 295404 imágenes candidatas.
# Imágenes organizadas en 93 BBOXes únicos.
#
# Iniciando descarga. Tiempo límite: 300 minutos.
#
# Iniciando Ronda 'Round Robin' Nivel 0...
# Progreso: 90 imágenes procesadas... Tiempo restante: 17946s
# Iniciando Ronda 'Round Robin' Nivel 1...
# Progreso: 185 imágenes procesadas... Tiempo restante: 17889s
# Iniciando Ronda 'Round Robin' Nivel 2...
# Progreso: 275 imágenes procesadas... Tiempo restante: 17835s
# Iniciando Ronda 'Round Robin' Nivel 3...
# Progreso: 370 imágenes procesadas... Tiempo restante: 17729s
# Iniciando Ronda 'Round Robin' Nivel 4...
# Progreso: 465 imágenes procesadas... Tiempo restante: 17613s
# Iniciando Ronda 'Round Robin' Nivel 5...
# Progreso: 555 imágenes procesadas... Tiempo restante: 17503s
# Iniciando Ronda 'Round Robin' Nivel 6...
# Progreso: 650 imágenes procesadas... Tiempo restante: 17388s
# Iniciando Ronda 'Round Robin' Nivel 7...
# Progreso: 740 imágenes procesadas... Tiempo restante: 17278s
# Iniciando Ronda 'Round Robin' Nivel 8...
# Progreso: 835 imágenes procesadas... Tiempo restante: 17160s
# Iniciando Ronda 'Round Robin' Nivel 9...
# Progreso: 925 imágenes procesadas... Tiempo restante: 17051s
# Iniciando Ronda 'Round Robin' Nivel 10...
# Progreso: 1020 imágenes procesadas... Tiempo restante: 16932s
# Iniciando Ronda 'Round Robin' Nivel 11...
# Progreso: 1110 imágenes procesadas... Tiempo restante: 16816s
# Iniciando Ronda 'Round Robin' Nivel 12...
# Progreso: 1200 imágenes procesadas... Tiempo restante: 16703s
# Iniciando Ronda 'Round Robin' Nivel 13...
# Progreso: 1290 imágenes procesadas... Tiempo restante: 16593s
# Iniciando Ronda 'Round Robin' Nivel 14...
# Progreso: 1385 imágenes procesadas... Tiempo restante: 16474s
# Iniciando Ronda 'Round Robin' Nivel 15...
# Progreso: 1475 imágenes procesadas... Tiempo restante: 16359s
# Iniciando Ronda 'Round Robin' Nivel 16...
# Progreso: 1565 imágenes procesadas... Tiempo restante: 16244s
# Iniciando Ronda 'Round Robin' Nivel 17...
# Progreso: 1655 imágenes procesadas... Tiempo restante: 16133s
# Iniciando Ronda 'Round Robin' Nivel 18...
# Progreso: 1745 imágenes procesadas... Tiempo restante: 16022s
# Iniciando Ronda 'Round Robin' Nivel 19...
# Progreso: 1840 imágenes procesadas... Tiempo restante: 15902s
# Iniciando Ronda 'Round Robin' Nivel 20...
# Progreso: 1930 imágenes procesadas... Tiempo restante: 15790s
# Iniciando Ronda 'Round Robin' Nivel 21...
# Progreso: 2020 imágenes procesadas... Tiempo restante: 15676s
# Iniciando Ronda 'Round Robin' Nivel 22...
# Progreso: 2110 imágenes procesadas... Tiempo restante: 15562s
# Iniciando Ronda 'Round Robin' Nivel 23...
# Progreso: 2200 imágenes procesadas... Tiempo restante: 15448s
# Progreso: 6755 imágenes procesadas... Tiempo restante: 9831s
# Iniciando Ronda 'Round Robin' Nivel 75...
# Progreso: 6840 imágenes procesadas... Tiempo restante: 9727s
# Iniciando Ronda 'Round Robin' Nivel 76...
# Progreso: 6930 imágenes procesadas... Tiempo restante: 9619s
# Iniciando Ronda 'Round Robin' Nivel 77...
# Progreso: 7015 imágenes procesadas... Tiempo restante: 9517s
# Iniciando Ronda 'Round Robin' Nivel 78...
# Progreso: 7100 imágenes procesadas... Tiempo restante: 9413s
# Iniciando Ronda 'Round Robin' Nivel 79...
# Progreso: 7190 imágenes procesadas... Tiempo restante: 9302s
# Iniciando Ronda 'Round Robin' Nivel 80...
# Progreso: 7275 imágenes procesadas... Tiempo restante: 9197s
# Iniciando Ronda 'Round Robin' Nivel 81...
# Progreso: 7360 imágenes procesadas... Tiempo restante: 9085s
# Iniciando Ronda 'Round Robin' Nivel 82...
# Progreso: 7445 imágenes procesadas... Tiempo restante: 8984s
# Iniciando Ronda 'Round Robin' Nivel 83...
# Progreso: 7535 imágenes procesadas... Tiempo restante: 8871s
# Iniciando Ronda 'Round Robin' Nivel 84...
# Progreso: 7620 imágenes procesadas... Tiempo restante: 8762s
# Iniciando Ronda 'Round Robin' Nivel 85...
# Progreso: 7705 imágenes procesadas... Tiempo restante: 8658s
# Iniciando Ronda 'Round Robin' Nivel 86...
# Progreso: 7790 imágenes procesadas... Tiempo restante: 8555s
# Iniciando Ronda 'Round Robin' Nivel 87...
# Progreso: 7875 imágenes procesadas... Tiempo restante: 8448s
# Iniciando Ronda 'Round Robin' Nivel 88...
# Progreso: 7965 imágenes procesadas... Tiempo restante: 8335s
# Iniciando Ronda 'Round Robin' Nivel 89...
# Progreso: 8050 imágenes procesadas... Tiempo restante: 8230s
# Iniciando Ronda 'Round Robin' Nivel 90...
# Progreso: 8135 imágenes procesadas... Tiempo restante: 8127s
# Iniciando Ronda 'Round Robin' Nivel 91...
# Progreso: 8220 imágenes procesadas... Tiempo restante: 8022s
# Iniciando Ronda 'Round Robin' Nivel 92...
# Progreso: 8305 imágenes procesadas... Tiempo restante: 7918s
# Iniciando Ronda 'Round Robin' Nivel 93...
# Progreso: 8395 imágenes procesadas... Tiempo restante: 7807s
# Iniciando Ronda 'Round Robin' Nivel 94...
# Progreso: 8480 imágenes procesadas... Tiempo restante: 7700s
# Iniciando Ronda 'Round Robin' Nivel 95...
# Progreso: 8565 imágenes procesadas... Tiempo restante: 7594s
# Iniciando Ronda 'Round Robin' Nivel 96...
# Progreso: 8650 imágenes procesadas... Tiempo restante: 7491s
# Iniciando Ronda 'Round Robin' Nivel 97...
# Progreso: 8735 imágenes procesadas... Tiempo restante: 7387s
# Iniciando Ronda 'Round Robin' Nivel 98...
# Progreso: 8825 imágenes procesadas... Tiempo restante: 7274s
# Iniciando Ronda 'Round Robin' Nivel 99...
# Progreso: 8910 imágenes procesadas... Tiempo restante: 7170s
# Progreso: 11105 imágenes procesadas... Tiempo restante: 4471s
# Iniciando Ronda 'Round Robin' Nivel 126...
# Progreso: 11190 imágenes procesadas... Tiempo restante: 4367s
# Iniciando Ronda 'Round Robin' Nivel 127...
# Progreso: 11275 imágenes procesadas... Tiempo restante: 4263s
# Iniciando Ronda 'Round Robin' Nivel 128...
# Progreso: 11355 imágenes procesadas... Tiempo restante: 4163s
# Iniciando Ronda 'Round Robin' Nivel 129...
# Progreso: 11440 imágenes procesadas... Tiempo restante: 4059s
# Iniciando Ronda 'Round Robin' Nivel 130...
# Progreso: 11525 imágenes procesadas... Tiempo restante: 3954s
# Iniciando Ronda 'Round Robin' Nivel 131...
# Progreso: 11610 imágenes procesadas... Tiempo restante: 3848s
# Iniciando Ronda 'Round Robin' Nivel 132...
# Progreso: 11695 imágenes procesadas... Tiempo restante: 3744s
# Iniciando Ronda 'Round Robin' Nivel 133...
# Progreso: 11775 imágenes procesadas... Tiempo restante: 3644s
# Iniciando Ronda 'Round Robin' Nivel 134...
# Progreso: 11860 imágenes procesadas... Tiempo restante: 3538s
# Iniciando Ronda 'Round Robin' Nivel 135...
# Progreso: 11945 imágenes procesadas... Tiempo restante: 3433s
# Iniciando Ronda 'Round Robin' Nivel 136...
# Progreso: 12030 imágenes procesadas... Tiempo restante: 3329s
# Iniciando Ronda 'Round Robin' Nivel 137...
# Progreso: 12115 imágenes procesadas... Tiempo restante: 3225s
# Iniciando Ronda 'Round Robin' Nivel 138...
# Progreso: 12195 imágenes procesadas... Tiempo restante: 3128s
# Iniciando Ronda 'Round Robin' Nivel 139...
# Progreso: 12280 imágenes procesadas... Tiempo restante: 3025s
# Iniciando Ronda 'Round Robin' Nivel 140...
# Progreso: 12365 imágenes procesadas... Tiempo restante: 2921s
# Iniciando Ronda 'Round Robin' Nivel 141...
# Progreso: 12450 imágenes procesadas... Tiempo restante: 2816s
# Iniciando Ronda 'Round Robin' Nivel 142...
# Progreso: 12530 imágenes procesadas... Tiempo restante: 2717s
# Iniciando Ronda 'Round Robin' Nivel 143...
# Progreso: 12615 imágenes procesadas... Tiempo restante: 2610s
# Iniciando Ronda 'Round Robin' Nivel 144...
# Progreso: 12695 imágenes procesadas... Tiempo restante: 2512s
# Iniciando Ronda 'Round Robin' Nivel 145...
# Progreso: 12780 imágenes procesadas... Tiempo restante: 2405s
# Iniciando Ronda 'Round Robin' Nivel 146...
# Progreso: 12865 imágenes procesadas... Tiempo restante: 2298s
# Iniciando Ronda 'Round Robin' Nivel 147...
# Progreso: 12945 imágenes procesadas... Tiempo restante: 2199s
# Iniciando Ronda 'Round Robin' Nivel 148...
# Progreso: 13030 imágenes procesadas... Tiempo restante: 2093s
# Iniciando Ronda 'Round Robin' Nivel 149...
# Progreso: 13110 imágenes procesadas... Tiempo restante: 1994s
# Iniciando Ronda 'Round Robin' Nivel 150...
# Progreso: 13195 imágenes procesadas... Tiempo restante: 1887s
# Iniciando Ronda 'Round Robin' Nivel 151...
# Progreso: 13280 imágenes procesadas... Tiempo restante: 1779s
# Iniciando Ronda 'Round Robin' Nivel 152...
# Progreso: 13360 imágenes procesadas... Tiempo restante: 1678s
# Iniciando Ronda 'Round Robin' Nivel 153...
# Progreso: 13440 imágenes procesadas... Tiempo restante: 1579s
# Iniciando Ronda 'Round Robin' Nivel 154...
# Progreso: 13525 imágenes procesadas... Tiempo restante: 1472s
# Iniciando Ronda 'Round Robin' Nivel 155...
# Progreso: 13605 imágenes procesadas... Tiempo restante: 1369s
# Iniciando Ronda 'Round Robin' Nivel 156...
# Progreso: 13690 imágenes procesadas... Tiempo restante: 1260s
# Iniciando Ronda 'Round Robin' Nivel 157...
# Progreso: 13770 imágenes procesadas... Tiempo restante: 1157s
# Iniciando Ronda 'Round Robin' Nivel 158...
# Progreso: 13850 imágenes procesadas... Tiempo restante: 1053s
# Iniciando Ronda 'Round Robin' Nivel 159...
# Progreso: 13935 imágenes procesadas... Tiempo restante: 947s
# Iniciando Ronda 'Round Robin' Nivel 160...
# Progreso: 14015 imágenes procesadas... Tiempo restante: 845s
# Iniciando Ronda 'Round Robin' Nivel 161...
# Progreso: 14100 imágenes procesadas... Tiempo restante: 739s
# Iniciando Ronda 'Round Robin' Nivel 162...
# Progreso: 14180 imágenes procesadas... Tiempo restante: 636s
# Iniciando Ronda 'Round Robin' Nivel 163...
# Progreso: 14260 imágenes procesadas... Tiempo restante: 533s
# Iniciando Ronda 'Round Robin' Nivel 164...
# Progreso: 14345 imágenes procesadas... Tiempo restante: 428s
# Iniciando Ronda 'Round Robin' Nivel 165...
# Progreso: 14425 imágenes procesadas... Tiempo restante: 327s
# Iniciando Ronda 'Round Robin' Nivel 166...
# Progreso: 14510 imágenes procesadas... Tiempo restante: 217s
# Iniciando Ronda 'Round Robin' Nivel 167...
# Progreso: 14590 imágenes procesadas... Tiempo restante: 116s
# Iniciando Ronda 'Round Robin' Nivel 168...
# Progreso: 14670 imágenes procesadas... Tiempo restante: 16s
# Iniciando Ronda 'Round Robin' Nivel 169...
# Progreso: 14680 imágenes procesadas... Tiempo restante: 1s
# ¡Tiempo límite alcanzado! Deteniendo el bucle 'for' interno.
#
# ¡Tiempo límite alcanzado! Deteniendo el bucle 'while' externo.
#
# Proceso detenido. Guardando metadata de 14680 imágenes procesadas...
# Guardando metadata en '/kaggle/working/metadata_muestra_por_tiempo.json'...
#
# ==============================
# --- MUESTREO POR TIEMPO COMPLETADO ---
# Tiempo Objetivo: 300.00 minutos.
# Tiempo Real de Ejecución: 300.00 minutos (18000 segundos).
# Imágenes Únicas Descargadas: 14680
# Total Imágenes Procesadas (Metadata): 14680
# Imágenes guardadas en: '/kaggle/working/imagenes_muestreadas_por_tiempo'
# Metadata guardada en: '/kaggle/working/metadata_muestra_por_tiempo.json'
# ==============================
